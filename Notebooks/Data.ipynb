# %%
from sklearn.datasets import load_breast_cancer

# %%
df = load_breast_cancer(as_frame=True).frame

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(14,8))
plt
# Out:
# <module 'matplotlib.pyplot' from '/Users/adityaprajapati/Documents/ML Learning/Scikit_Learn_Tutorial/.venv/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X, y = load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_tet = train_test_split(X, y, test_size=0.2)

scalar = StandardScaler()

X_train_scaled = scalar.fit_transform(X_train)
X_test_scaled = scalar.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

clf = KNeighborsClassifier()

clf.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
clf.score(X_test_scaled, y_tet)
# Out:
# 0.956140350877193

# %%
single_inst = X_test_scaled[1]

# %%
single_inst
# Out:
# array([ 0.01147619, -0.26060838, -0.05445217, -0.08559931, -2.13356824,
#        -0.97305624, -0.79363243, -0.9031682 , -0.62881427, -0.96325739,
#        -0.64334104, -1.01636872, -0.59703859, -0.44159418, -1.27658379,
#        -0.63447749, -0.6768585 , -1.0549165 , -1.18678018, -0.65946957,
#        -0.03035197, -0.05862767, -0.05952605, -0.12534872, -1.65240615,
#        -0.21232041, -0.54343724, -0.5997356 , -0.42480185, -0.36291591])

# %%
clf.predict([single_inst])
# Out:
# array([1])

# %%
y_tet[1]
# Out:
# np.int64(1)

# %%
clf.predict_proba([single_inst])
# Out:
# array([[0., 1.]])

# %%
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

pipe = Pipeline([
    ("scale", StandardScaler()),
    ("pca", PCA(n_components=10)),
    ("forest", RandomForestClassifier())
])

pipe.fit(X_train_scaled, y_train)
# Out:
# /Users/adityaprajapati/Documents/ML Learning/Scikit_Learn_Tutorial/.venv/lib/python3.9/site-packages/sklearn/decomposition/_pca.py:606: RuntimeWarning: divide by zero encountered in matmul
#   C = X.T @ X
# /Users/adityaprajapati/Documents/ML Learning/Scikit_Learn_Tutorial/.venv/lib/python3.9/site-packages/sklearn/decomposition/_pca.py:606: RuntimeWarning: overflow encountered in matmul
#   C = X.T @ X
# /Users/adityaprajapati/Documents/ML Learning/Scikit_Learn_Tutorial/.venv/lib/python3.9/site-packages/sklearn/decomposition/_pca.py:606: RuntimeWarning: invalid value encountered in matmul
#   C = X.T @ X
# /Users/adityaprajapati/Documents/ML Learning/Scikit_Learn_Tutorial/.venv/lib/python3.9/site-packages/sklearn/decomposition/_base.py:148: RuntimeWarning: divide by zero encountered in matmul
#   X_transformed = X @ self.components_.T
# /Users/adityaprajapati/Documents/ML Learning/Scikit_Learn_Tutorial/.venv/lib/python3.9/site-packages/sklearn/decomposition/_base.py:148: RuntimeWarning: overflow encountered in matmul
#   X_transformed = X @ self.components_.T
# /Users/adityaprajapati/Documents/ML Learning/Scikit_Learn_Tutorial/.venv/lib/python3.9/site-packages/sklearn/decomposition/_base.py:148: RuntimeWarning: invalid value encountered in matmul
#   X_transformed = X @ self.components_.T
# Pipeline(steps=[('scale', StandardScaler()), ('pca', PCA(n_components=10)),
#                 ('forest', RandomForestClassifier())])
